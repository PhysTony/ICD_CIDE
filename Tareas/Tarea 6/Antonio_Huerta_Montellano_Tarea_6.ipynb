# %% [markdown]
# ## Tarea 5 - Antonio Huerta Montellano

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# 1. Lee el archivo tips en formato csv a través de un Dataframe de Pandas:

# %%
dataframe = pd.read_csv("tips.csv")

# %% [markdown]
# 2. Muestra los primeros cinco renglones:

# %%
dataframe.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %% [markdown]
# 3. Hacer una visualización de dos histogramas con 10 bins de las variables 'total_bill' y 'tip':
#     - Deben incluir títulos y etiquetas para los ejes de las Xs y de las Ys.
#     - Ponerlos de distinto color.

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15,7))
axes[0].hist(dataframe['tip'], bins=10, color='orange')
axes[1].hist(dataframe['total_bill'], bins=10, color='skyblue')
axes[0].set_ylabel('Frecuencia', fontsize = 16, fontweight = 'bold')
axes[0].set_xlabel('Tips', fontsize = 16, fontweight = 'bold')  
axes[1].set_xlabel('Total bill[$\$$]', fontsize = 16, fontweight = 'bold')
axes[0].tick_params(labelsize = 12)
axes[1].tick_params(labelsize = 12)
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# 4. Hacer visualización de un diagrama de dispersión con variables 'total_bill' y 'tip', agregar título y etiquetas en los ejes.

# %%
plt.figure(figsize=(15,8))
plt.title("Total bill vs tip", fontsize = 25, fontweight = 'bold')
plt.xlabel("Tips", fontsize = 16, fontweight = 'bold')
plt.ylabel("Total bill[$\$$]", fontsize = 16, fontweight = 'bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.scatter(dataframe['tip'], dataframe['total_bill'], 
            color = 'purple', alpha=0.75)
plt.show()

# %% [markdown]
# 5. Hacer una visualización con boxplot (mediana, cuartiles y outliers) en un mismo panel para la variable 'tip' en donde se divide por fumadores ('smoker') y no fumadores. Poner una etiqueta a cada categoría, y etiquetas en los ejes Xs y Ys así como el título.
#
# **Para este ejercicio --no usar seaborn—**

# %%
yes = dataframe['smoker'] == 'Yes' 
no = dataframe['smoker'] == 'No' 
new_data = [dataframe[no]['tip'],
           dataframe[yes]['tip']]
red_square = dict(markerfacecolor='r', marker='s')

# %%
plt.figure(figsize=(15, 7))
box = plt.boxplot(new_data,
                  labels=['No fumador','Sí fumador'],
                  patch_artist=True,
                  flierprops=red_square)
plt.title("Tips by Smoker", fontsize = 25, fontweight = 'bold')
plt.ylabel('Cuantil', fontsize = 18, fontweight = 'bold')
plt.xticks(fontsize=18, fontweight='bold')
plt.yticks(fontsize=14)
plt.grid()
plt.show()

# %%
red_square = dict(markerfacecolor='r', marker='s')

# %%
fig, axes = plt.subplots(1, 2, sharey=True, figsize=(15,7))
axes[0].boxplot(dataframe[dataframe['smoker'] == 'No'].tip, flierprops=red_square)
axes[1].boxplot(dataframe[dataframe['smoker'] == 'Yes'].tip, flierprops=red_square)
axes[0].set_ylabel('Cuantil', fontsize = 16, fontweight = 'bold')
axes[0].set_xlabel('Tips', fontsize = 16, fontweight = 'bold')  
axes[1].set_xlabel('Tips', fontsize = 16, fontweight = 'bold')
axes[0].set_title('Smoker = No', fontsize = 18, fontweight = 'bold')  
axes[1].set_title('Smoker = Yes', fontsize = 18, fontweight = 'bold')
axes[0].tick_params(labelsize = 12)
axes[1].tick_params(labelsize = 12)
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# 6. Hacer un diagrama de dispersión con variables 'total_bill' y 'tip', en el que el color del punto se elige a partir de la variable 'time' y el tamaño del punto en función de la variable 'size'. Agregar título y etiquetas en los ejes.

# %%
color_etiqueta = dataframe['time'].unique()
colors = {color_etiqueta[0]: 'purple', color_etiqueta[1]: 'red'}

# %%
print(color_etiqueta)
print(len(color_etiqueta))
# Out:
# ['Dinner' 'Lunch']
# 2

# %%
plt.figure(figsize=(15,8))
plt.title("Total bill vs tip", fontsize = 25, fontweight = 'bold')
plt.xlabel("Tips", fontsize = 16, fontweight = 'bold')
plt.ylabel("Total bill[$\$$]", fontsize = 16, fontweight = 'bold')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.scatter(dataframe['tip'], dataframe['total_bill'], 
            c = dataframe['time'].map(colors),
            s = dataframe.size*0.3,
            alpha=0.1)
plt.show()
